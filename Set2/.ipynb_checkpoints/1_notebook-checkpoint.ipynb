# %% [markdown]
# # Problem 1

# %% [markdown]
# Use this notebook to write your code for problem 1. Some example code, and a plotting function for drawing decision boundaries, are given below.

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
# %matplotlib inline

# %% [markdown]
# ### Load the data:

# %%
import os   #slight change to get to the directory
data = np.loadtxt(os.getcwd() + '/data/problem1data1.txt')
X = data[:, :2]
y = data[:, 2]

# %% [markdown]
# ### The function make_plot below is a helper function for plotting decision boundaries; you should not need to change it.

# %%
def make_plot(X, y, clf, title, filename):
    '''
    Plots the decision boundary of the classifier <clf> (assumed to have been fitted
    to X via clf.fit()) against the matrix of examples X with corresponding labels y.

    Uses <title> as the title of the plot, saving the plot to <filename>.

    Note that X is expected to be a 2D numpy array of shape (num_samples, num_dims).
    '''
    # Create a mesh of points at which to evaluate our classifier
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    # binarize 
    Z = np.where(Z > 0, np.ones(len(Z)), -1 * np.ones(len(Z)))
    
    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8, vmin=-1, vmax=1)

    # Also plot the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(title)
    plt.savefig(filename)
    plt.show()

# %% [markdown]
# ## Here is some example code for performing regression with scikit-learn.
# This section is not part of the problem! It demonstrates usage of the Ridge regression function, in particular illustrating what happens when the regularization strength is set to an overly-large number.

# %%
# Instantiate a Ridge regression object:
ridge = Ridge(alpha = 200)

# Generate some fake data: y is linearly dependent on x, plus some noise.
n_pts = 40

x = np.linspace(0, 5, n_pts)
y = 5 * x + np.random.randn(n_pts) + 2

x = np.reshape(x, (-1, 1))   # Ridge regression function expects a 2D matrix

plt.figure()
plt.plot(x, y, marker = 'o', linewidth = 0)

ridge.fit(x, y)   # Fit the ridge regression model to the data
print('Ridge regression fit y = %fx + %f' % (ridge.coef_, ridge.intercept_))

# Add ridge regression line to the plot:
plt.plot(x, ridge.coef_ * x + ridge.intercept_, color = 'red')
plt.legend(['data', 'Ridge Regression Fit'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ridge Regression with High Regularization')
# Out:
# Ridge regression fit y = 1.548487x + 10.595316

# %% [markdown]
# # Your code for problem 1

# %%
# logistic regression object

log = LogisticRegression(C = 1000)   #specify small amount of regularization
log.fit(X, y)
make_plot(X, y, log, 'Logistic Regression with Low Regularization', 'log_reg' )

# ridge regression object

ridge = Ridge(alpha = 0.001)        #specify regularization; alpha is inverse of C
ridge.fit(X,y)
make_plot(X, y, ridge, 'Ridge Regression with Low Regularization', 'ridge_reg' )
# Out:
# /Users/Timothy/anaconda/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /Users/Timothy/anaconda/lib/python3.5/site-packages/numpy/ma/core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
def hinge_grad(w, x, y):
    '''calculates gradient of hinge loss at a single point
    inputs: w - weight vector
            x - x coordinate
            y - classification
    outputs: grad - gradient of loss at single point'''
    if 1 - y * np.dot(np.transpose(w), x) > 0:
        grad = -1 * y * x
    else:
        grad = [0, 0, 0]
        
    norm = np.linalg.norm(grad)
        
    return grad, norm
        
def log_grad(w, x, y):
    '''calculates gradient of hinge loss at a single point
    inputs: w - weight vector
            x - x coordinate
            y - classification'''
    #print(x * np.dot(np.transpose(w), x))
    num = -1 * y * np.exp(-1 * y * np.dot(np.transpose(w), x)) * x
    den = (1 + np.exp(-1 * y * np.dot(np.transpose(w), x)))
    
    grad = num/den
    norm = np.linalg.norm(grad)
    
    return grad, norm


#x-coors with zero coordinate included
Xc = np.array([[1, 0.5, 3], [1, 2, -2], [1, -3, 1]])
#y-classifications
yc = np.array([1, 1, -1])
#weight vector
w = np.array([0, 1, 0])

for i in range(3):
    print(Xc[i], yc[i])
    grad, norm = hinge_grad(w, Xc[i], yc[i])
    print("Hinge Grad: ", grad, "Mag: ", norm)
    grad, norm = log_grad(w, Xc[i], yc[i])
    print("Log Grad: ", grad, "Mag: ", norm, '\n')
# Out:
# [ 1.   0.5  3. ] 1
# Hinge Grad:  [-1.  -0.5 -3. ] Mag:  3.20156211872
# norm 1.2087199035
# Log Grad:  [-0.37754067 -0.18877033 -1.13262201] Mag:  1.2087199035
#
# [ 1.  2. -2.] 1
# Hinge Grad:  [0, 0, 0] Mag:  0.0
# norm 0.357608766066
# Log Grad:  [-0.11920292 -0.23840584  0.23840584] Mag:  0.357608766066
#
# [ 1. -3.  1.] -1
# Hinge Grad:  [0, 0, 0] Mag:  0.0
# norm 0.157293826685
# Log Grad:  [ 0.04742587 -0.14227762  0.04742587] Mag:  0.157293826685
